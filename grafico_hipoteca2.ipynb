# %% [markdown]
# <a href="https://colab.research.google.com/github/Xavialva/Grafico2/blob/main/grafico_hipoteca2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df='/content/drive/MyDrive/PTDataScience/VisualDatos/mortgages (4).csv'

# %%
df= pd.read_csv(df)

# %%
df
# Out:
#       Month  Starting Balance  ...  Mortgage Name  Interest Rate
# 0         1         400000.00  ...        30 Year           0.03
# 1         2         399313.58  ...        30 Year           0.03
# 2         3         398625.44  ...        30 Year           0.03
# 3         4         397935.58  ...        30 Year           0.03
# 4         5         397243.99  ...        30 Year           0.03
# ...     ...               ...  ...            ...            ...
# 1075    176          15619.91  ...        15 Year           0.05
# 1076    177          12521.82  ...        15 Year           0.05
# 1077    178           9410.82  ...        15 Year           0.05
# 1078    179           6286.86  ...        15 Year           0.05
# 1079    180           3149.88  ...        15 Year           0.05
#
# [1080 rows x 8 columns]

# %%
df.loc[(df['Mortgage Name']=='30 Year')&(df['Interest Rate']== 0.03)]
# Out:
#      Month  Starting Balance  ...  Mortgage Name  Interest Rate
# 0        1         400000.00  ...        30 Year           0.03
# 1        2         399313.58  ...        30 Year           0.03
# 2        3         398625.44  ...        30 Year           0.03
# 3        4         397935.58  ...        30 Year           0.03
# 4        5         397243.99  ...        30 Year           0.03
# ..     ...               ...  ...            ...            ...
# 355    356           8364.12  ...        30 Year           0.03
# 356    357           6698.61  ...        30 Year           0.03
# 357    358           5028.93  ...        30 Year           0.03
# 358    359           3355.08  ...        30 Year           0.03
# 359    360           1677.04  ...        30 Year           0.03
#
# [360 rows x 8 columns]

# %%
df1=df.loc[(df['Mortgage Name']=='30 Year')&(df['Interest Rate']== 0.03)]

# %%
df1['Interes acumulado']= df1['Interest Paid'].cumsum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df1
# Out:
#      Month  Starting Balance  ...  Interest Rate  Interes acumulado
# 0        1         400000.00  ...           0.03            1000.00
# 1        2         399313.58  ...           0.03            1998.28
# 2        3         398625.44  ...           0.03            2994.84
# 3        4         397935.58  ...           0.03            3989.67
# 4        5         397243.99  ...           0.03            4982.77
# ..     ...               ...  ...            ...                ...
# 355    356           8364.12  ...           0.03          207064.13
# 356    357           6698.61  ...           0.03          207080.87
# 357    358           5028.93  ...           0.03          207093.44
# 358    359           3355.08  ...           0.03          207101.82
# 359    360           1677.04  ...           0.03          207106.01
#
# [360 rows x 9 columns]

# %%
df2=df.loc[(df['Mortgage Name']=='30 Year')&(df['Interest Rate']== 0.05)]

# %%
df2['Interes acumulado']=df2['Interest Paid'].cumsum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2
# Out:
#      Month  Starting Balance  ...  Interest Rate  Interes acumulado
# 360      1         400000.00  ...           0.05            1666.66
# 361      2         399519.37  ...           0.05            3331.32
# 362      3         399036.74  ...           0.05            4993.97
# 363      4         398552.10  ...           0.05            6654.60
# 364      5         398065.44  ...           0.05            8313.20
# ..     ...               ...  ...            ...                ...
# 715    356          10596.54  ...           0.05          372928.64
# 716    357           8493.40  ...           0.05          372964.02
# 717    358           6381.49  ...           0.05          372990.60
# 718    359           4260.78  ...           0.05          373008.35
# 719    360           2131.24  ...           0.05          373017.23
#
# [360 rows x 9 columns]

# %%
plt.style.use('classic')
plt.plot(df1['Month'],df1['Interes acumulado'],c='c',label= '30 Year 3% APR')
plt.plot(df2['Month'],df2['Interes acumulado'],c='g',label= '30 Year 5% APR')
plt.xlabel('Meses', fontsize= 20)
plt.ylabel('Dólares',fontsize= 20)
plt.title('Pago de Interés Acumulado', fontsize=20)
plt.legend(loc='lower right')
plt.grid()
